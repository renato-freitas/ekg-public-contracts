# %% [markdown]
# # Agentic AI System

# %%
# ! pip install -U langgraph
# ! pip install -U langchain
# ! pip install -U langchain-groq

# %% [markdown]
# ## 1. Define Teams of the Workflows

# %%
from langgraph.graph import StateGraph

workflow_publation   = StateGraph()
workflow_integration = StateGraph()
workflow_fusion      = StateGraph()


team_publication = Crew()
team_integration = Crew()
team_fusion      = Crew()


team_publation   = workflow_publation.compile()
team_integration = workflow_integration.compile()
team_fusion      = workflow_fusion.compile()

# %% [markdown]
# ## 2. Define Agents

# %%
from langchain.agents import create_agent

## 1. Team of publication
# 1.1 ontologization
dataset_schema_extrator_agent = create_agent()
dataset_to_owl_agent          = create_agent()
suggest_vocabulary_agent      = create_agent()

# 1.2 Aligment of the SVO [Tulio]

# 1.3 Mapping [Asley]
# 1.4 Publication (Materialized or Virtual)


## 2. Team of Integration
# 2.1 Linkset View
# 2.2 Publication (Materialized or Virtual)
# 2.3 Generate Unification View

## 3. Team of Fusion
# 3.1 Property Assertion Fusion

# %%
from IPython.display import Image, display
